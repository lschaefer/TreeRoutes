# %% [markdown]
# <a href="https://colab.research.google.com/github/lschaefer/TreeRoutes/blob/master/Copy_of_train_placesSceneryScoreCNNColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
# !git clone https://github.com/lschaefer/TreeRoutes
# Out:
# Cloning into 'TreeRoutes'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 212175 (delta 0), reused 0 (delta 0), pack-reused 212172
# Receiving objects: 100% (212175/212175), 3.17 GiB | 45.17 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Checking out files: 100% (212117/212117), done.

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl 
# !pip3 install torchvision
# Out:
# ...
#      |████████████████████████████████| 592.3MB 1.1MB/s
# ...
# ERROR: torchvision 0.5.0 has requirement torch==1.4.0, but you'll have torch 0.3.0.post4 which is incompatible.
# ERROR: fastai 1.0.60 has requirement torch>=1.0.0, but you'll have torch 0.3.0.post4 which is incompatible.
# ...
#   Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
# ...
#      |████████████████████████████████| 753.4MB 9.9kB/s
# ...
#   Found existing installation: torch 0.3.0.post4
#     Uninstalling torch-0.3.0.post4:
#       Successfully uninstalled torch-0.3.0.post4
# ...

# %%
# !ls 
# !pwd
# Out:
# sample_data  TreeRoutes
# /content

# %%
# %cd TreeRoutes/
# Out:
# /content/TreeRoutes

# %%
# !git clone https://github.com/lschaefer/places365
# Out:
# Cloning into 'places365'...
# remote: Enumerating objects: 381, done.
# remote: Total 381 (delta 0), reused 0 (delta 0), pack-reused 381
# Receiving objects: 100% (381/381), 40.97 MiB | 40.38 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %%
# %cd places365/
# Out:
# /content/TreeRoutes/places365

# %%
# !ls ../data/sond/
# Out:
# train  val

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/lschaefer/places365
#    d0383ff..0889fa2  master     -> origin/master
# Updating d0383ff..0889fa2
# Fast-forward
#  train_placesCNNColab.py | 10 +++++-----
#  1 file changed, 5 insertions(+), 5 deletions(-)

# %%
# !python train_placesCNNColab.py -a resnet18 ../data/sond/ --resume resnet18_latest.pth.tar
# Out:
# => creating model 'resnet18'
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
from google.colab import files
files.download( "resnet18_latest.pth.tar")
files.download( "resnet18_best.pth.tar")
files.download( "errorVsEpoch.pdf")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-5a8a2f756852> in <module>()
#       1 from google.colab import files
# ----> 2 files.download( "resnet18_latest.pth.tar")
#       3 files.download( "resnet18_best.pth.tar")
#       4 files.download( "errorVsEpoch.pdf")
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
# ...

# %%
# !ls
# Out:
# adjectives_download.csv		      places365CNN_mean.binaryproto
# cam_example.jpg			      __pycache__
# categories_hybrid1365.txt	      README.md
# categories_places365.txt	      resnet18_best.pth.tar
# convert_model.py		      resnet18_latest.pth.tar
# convert_python36.py		      retrainCNN.py
# deploy_alexnet_places365.prototxt     run_placesCNN_basic_gen.py
# deploy_googlenet_places365.prototxt   run_placesCNN_basic.py
# deploy_resnet152_hybrid1365.prototxt  run_placesCNN_unified.py
# deploy_resnet152_places365.prototxt   scenicScoreDataset.py
# deploy_vgg16_hybrid1365.prototxt      solver_alexnet.prototxt
# deploy_vgg16_places365.prototxt       solver_vgg16.prototxt
# docker				      train_placesCNNColab.py
# errorVsEpoch.pdf		      train_placesCNN.py
# __init__.py			      train_val_alexnet.prototxt
# IO_places365.txt		      train_val_vgg16.prototxt
# labels_sunattribute.txt		      wideresnet.py
# LICENSE

# %%
files.download('resnet18_best.pth.tar')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-10-0fe29647b6b6> in <module>()
# ----> 1 files.download('resnet18_best.pth.tar')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
# ...

# %%
files.download('resnet18_latest.pth.tar')

# %%
files.download('resnet18_best.pth.tar')

# %%
files.download('errorVsEpoch.pdf')
